# %% [markdown]
# # scCODA - Compositional analysis of single-cell data
#
# The scCODA package ([Büttner, Ostner et al., 2020](https://www.biorxiv.org/content/10.1101/2020.12.14.422688v2)) is intended to be used with cell composition from single-cell RNA-seq experiments, however there are no technical restrictions that prevent the use of data from other sources.

# %%
# Parameters
condition_1 = "Z1_WT_IMQ_CD45pos"
condition_2 = "Z1_WT_CD45pos"
comparison_name = f"{condition_1}-{condition_2}"
fdr_value = 0.2

print(comparison_name)
print(fdr_value)
# Out:
# Z1_WT_IMQ_CD45pos-Z1_WT_CD45pos
# 0.2

# %%
# Setup
import warnings
warnings.filterwarnings("ignore")
import session_info

import pandas as pd
import matplotlib.pyplot as plt
import arviz as az

from sccoda.util import comp_ana as mod
from sccoda.util import cell_composition_data as dat
from sccoda.util import data_visualization as viz
# Out:
# 2025-04-10 17:04:17.896696: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Data preparation

# %%
# Loading data --> cell counts by CELL TYPE
cell_counts = pd.read_csv("results/tables/post12_cd45pos_celltypes_counts.csv")
cell_counts.head()
# Out:
#            sample_id  cDC1  cDC2  Conventional CD4+ T cells  \
# 0  Z1_KO_IMQ_CD45pos    62   246                        142
# 1      Z1_WT_CD45pos    40    37                         48
# 2  Z1_WT_IMQ_CD45pos    71   293                         86
# 3  Z2_KO_IMQ_CD45pos    65   288                        116
# 4      Z2_WT_CD45pos    64    87                         55
#
#    Cytotoxic CD8+ T cells  Dendritic epidermal T cells  \
# 0                      20                          102
# 1                       9                         1334
# 2                      18                           99
# 3                      26                          109
# 4                       7                         1713
#
#    DoubleNegative T cells  Foxp3+ Tregs  ILC2  Langerhans cells  ...  pDC  \
# 0                      93           134    17               118  ...   11
# 1                     129            27    89                45  ...    1
# 2                     132           118    25               113  ...   12
# 3                      97           158    17               170  ...    9
# 4                      64            30   111                79  ...    1
#
#    Proliferative CD4+ T cells  Proliferative DγδT cells  \
# 0                          46                        99
# 1                          12                        30
# 2                          35                       106
# 3                          41                       148
# 4                           9                        28
#
#    Proliferative Macrophages  Resident M2-like Macrophages  \
# 0                         54                            72
# 1                         28                            53
# 2                         74                           129
# 3                         45                            41
# 4                         46                           114
#
#    Selenop+ M2-like Macrophages  Slamf9+ Macrophages  Tissue-resident cDC2  \
# 0                           563                  332                    38
# 1                           107                   28                    45
# 2                           518                  347                    39
# 3                           292                  240                    57
# 4                           208                   54                    97
#
#    Vγ4 T cells  Vγ6 T cells
# 0          208          233
# 1          117          127
# 2          209          229
# 3          437          392
# 4          123          197
#
# [5 rows x 29 columns]

# %%
cell_counts = cell_counts[(cell_counts["sample_id"] == condition_1) |
                          (cell_counts["sample_id"] == condition_2)]

# %% [markdown]
# To use the models in scCODA, we first have to convert the data into an anndata object. This can be done easily with the sccoda.util.cell_composition_data module. The resulting object separates our data components:
# * Cell counts are stored in data.X as a numpy array with the dimensions.
# * Covariates are stored in data.obs as a pandas DataFrame.
# * Additional information on the cell types can be stored in adata.var.

# %%
# Convert data to anndata object
data_all = dat.from_pandas(
    cell_counts, 
    covariate_columns=["sample_id"])

print(data_all)
# Out:
# AnnData object with n_obs × n_vars = 2 × 28
#     obs: 'sample_id'

# %% [markdown]
# ## Compositional data visualization
#
# Analyzing compositional data is not straightforward. scCODA provides some ways of visualizing the properties of a compositional dataset before analysis.

# %% [markdown]
# ### Stacked barplots
#
# The most common representation of cell count data in genomic research are stacked barplots.

# %%
# Stacked barplot for each sample
viz.stacked_barplot(
    data_all, 
    feature_name="sample_id"
)
figure = plt.gcf()
figure.set_size_inches(15, 7)
figure.savefig(f"results/figs/scCODA_celltypes_{comparison_name}_stackedbarplot.png",
              bbox_inches='tight')

# %% [markdown]
# ### Grouped boxplots
#
# While stached barplots are a nice and compact way of representing compositional data, they omit crucial information about the data variance. Also, comparing the abundance of cell types that are not on the top or bottom of the bars can be hard.

# %%
# Grouped boxplots. No facets, relative abundance, no dots.
viz.boxplots(
    data_all, 
    feature_name="sample_id", 
    cmap = "husl",
    plot_facets=False,
    y_scale="relative", # relative, log
    add_dots=False
)
figure = plt.gcf()
figure.set_size_inches(7, 5)
figure.savefig(f"results/figs/scCODA_celltypes_{comparison_name}_boxplot.png",
              bbox_inches='tight')

# %% [markdown]
# ## Finding a reference cell type
#
# The scCODA model requires a cell type to be set as the reference category. However, choosing this cell type is often difficult. A good first choice is a referenece cell type that closely preserves the changes in relative abundance during the compositional analysis.
#
# For this, it is important that the reference cell type is not rare, to avoid large relative changes being caused by small absolute changes. Also, the relative abundance of the reference should vary as little as possible across all samples.
#
# For this, it is important that the reference cell type is not rare, to avoid large relative changes being caused by small absolute changes. Also, the relative abundance of the reference should vary as little as possible across all samples.

# %%
# Reference cell type
viz.rel_abundance_dispersion_plot(
    data=data_all,
    abundant_threshold=0.9
)
figure = plt.gcf()
figure.set_size_inches(7, 5)

# %% [markdown]
# ## Model setup and inference
#
# We can now create the model and run inference on it. Creating a sccoda.util.comp_ana.CompositionalAnalysis class object sets up the compositional model and prepares everxthing for parameter inference. It needs these informations:
# * The **data object** from above.
# * The **formula parameter**. It specifies how the covariates are used in the model. It can process R-style formulas via the patsy package, e.g. formula="Cov1 + Cov2 + Cov3". Here, we simply use the “Condition” covariate of our dataset.
# * The **reference_cell_type parameter** is used to specify a cell type that is believed to be unchanged by the covariates in formula. This is necessary, because compositional analysis must always be performed relative to a reference (See Büttner, Ostner et al., 2020 for a more thorough explanation). If no knowledge about such a cell type exists prior to the analysis, taking a cell type that has a nearly constant relative abundance over all samples is often a good choice. It is also possible to let scCODA find a suited reference cell type by using reference_cell_type="automatic".
#
# **TWEAKING THE FORMULA PARAMETER**
#
# First, we take a closer look at how changing the formula parameter of the scCODA model influences the results. Internally, the formula string is converted into a linear model-like design matrix via patsy, which has a similar syntax to the lm function in the R language.
#
#     1. Multi-level categories
#
# Patsy allows us to automatically handle categorical covariates, even with multiple levels.
#
#     2. Different reference category levels
#
# Per default, categorical variables are encoded via full-rank sample_id coding. Hereby, the value of the first sample in the dataset is used as the reference (control) category. We can select the control level by changing the model formula to:
#
#     `"C(<CovariateName>, sample_id('<ReferenceLevelName>'))"`.
#
#
#
# **SWITCHING THE REFERENCE CELL TYPE PARAMETER**
#
# Compositional analysis generally does not allow statements on absolute abundance changes, but only in relation to a reference category, which is assumed to be unchanged in absolute abundance. The reference cell type fixes this category in scCODA. Thus, an interpretation of scCODA’s effects should always be formulated like:
#
# “Using cell type xy as a reference, cell types (a, b, c) were found to credibly change in abundance”
#
# Switching the reference cell type might thus produce different results. For example, if we choose a cell type that heavily increases in relative abundance as the reference, scCODA will likely find many credible negative effects on the other cell types.
#
#
# **Inference algorithms in scCODA**
#
# Currently, scCODA performs parameter inference via Markov-chain Monte Carlo (MCMC) methods. There are three different MCMC sampling methods available for scCODA:
# * Hamiltonian Monte Carlo (HMC) sampling: `sample_hmc()`
# * HMC sampling with Dual-averaging step size adaptation (Nesterov, 2009): `sample_hmc_da()`
# * No-U-Turn sampling (Hoffman and Gelman, 2014): `sample_nuts()`
#
# Generally, it is recommended to use the standard HMC sampling.

# %%
formula_parameter = "C(sample_id, Treatment('Z1_WT_CD45pos'))"
reference_cell_type_parameter = "Langerhans cells" # or  -- selected to match all comparisons

model = mod.CompositionalAnalysis(
    data_all, 
    formula = formula_parameter, 
    reference_cell_type = reference_cell_type_parameter
)

# %%
# Run MCMC
results = model.sample_hmc()
results.set_fdr(est_fdr=fdr_value)
# Out:
# WARNING:tensorflow:From /home/laurajg/miniconda3/envs/scanpy_March25/lib/python3.9/site-packages/tensorflow_probability/python/internal/batched_rejection_sampler.py:102: calling while_loop_v2 (from tensorflow.python.ops.control_flow_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.while_loop(c, b, vars, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.while_loop(c, b, vars))
# WARNING:tensorflow:From /home/laurajg/miniconda3/envs/scanpy_March25/lib/python3.9/site-packages/tensorflow_probability/python/internal/batched_rejection_sampler.py:102: calling while_loop_v2 (from tensorflow.python.ops.control_flow_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.while_loop(c, b, vars, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.while_loop(c, b, vars))
# 100%|████████████████████████████████████| 20000/20000 [00:42<00:00, 468.91it/s]
# MCMC sampling finished. (55.494 sec)
# Acceptance rate: 39.4%

# %% [markdown]
# ### Results interpretation
#
# **Model properties**
#
# First, the summary shows an overview over the model properties:
# * Number of samples/cell types
# * The reference cell type.
# * The formula used
#
# The model has two types of parameters that are relevant for analysis - intercepts and effects. These can be interpreted like in a standard regression model:
# * Intercepts show how the cell types are distributed without any active covariates.
# * Effects show how the covariates influence the cell types.
#
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries:
# * A value of zero means that no statistically credible effect was detected.
# * For a value other than zero, a credible change was detected.
#     * A positive sign indicates an increase
#     * A negative sign a decrease in abundance.
#
# Since the numerical values of the “Final parameter” columns are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, are expected to change in abundance as well.

# %%
# Results interpretation in a dataframe
results.effect_df
# Out:
#                                                                                  Final Parameter  \
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                                 0.000000
#                                                    cDC2                                 1.018600
#                                                    Conventional CD4+ T cells            0.000000
#                                                    Cytotoxic CD8+ T cells               0.000000
#                                                    Dendritic epidermal T cells         -3.340484
#                                                    DoubleNegative T cells              -0.881663
#                                                    Foxp3+ Tregs                         0.462517
#                                                    ILC2                                -1.810082
#                                                    Langerhans cells                     0.000000
#                                                    M1-like Macrophages                  1.654360
#                                                    Mast cells                          -1.538103
#                                                    Mature Monocytes                     0.000000
#                                                    MHCII+Ccr2+ Macrophages              0.946688
#                                                    mo-DCs                               0.735615
#                                                    Monocytes                            1.659227
#                                                    mregDCs                              0.774140
#                                                    Neutrophils                          2.170300
#                                                    NK cells                             0.000000
#                                                    pDC                                  0.000000
#                                                    Proliferative CD4+ T cells           0.000000
#                                                    Proliferative DγδT cells             0.000000
#                                                    Proliferative Macrophages            0.000000
#                                                    Resident M2-like Macrophages         0.000000
#                                                    Selenop+ M2-like Macrophages         0.665606
#                                                    Slamf9+ Macrophages                  1.472608
#                                                    Tissue-resident cDC2                -0.714962
#                                                    Vγ4 T cells                          0.000000
#                                                    Vγ6 T cells                          0.000000
#
#                                                                                  HDI 3%  \
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                          -1.542
#                                                    cDC2                          -0.019
#                                                    Conventional CD4+ T cells     -1.301
#                                                    Cytotoxic CD8+ T cells        -1.762
#                                                    Dendritic epidermal T cells   -4.065
#                                                    DoubleNegative T cells        -1.677
#                                                    Foxp3+ Tregs                  -0.674
#                                                    ILC2                          -2.931
#                                                    Langerhans cells               0.000
#                                                    M1-like Macrophages            0.541
#                                                    Mast cells                    -2.399
#                                                    Mature Monocytes              -0.798
#                                                    MHCII+Ccr2+ Macrophages        0.126
#                                                    mo-DCs                        -0.624
#                                                    Monocytes                      0.388
#                                                    mregDCs                       -0.615
#                                                    Neutrophils                    0.923
#                                                    NK cells                      -1.738
#                                                    pDC                           -1.508
#                                                    Proliferative CD4+ T cells    -1.491
#                                                    Proliferative DγδT cells      -0.854
#                                                    Proliferative Macrophages     -1.432
#                                                    Resident M2-like Macrophages  -0.911
#                                                    Selenop+ M2-like Macrophages  -0.025
#                                                    Slamf9+ Macrophages            0.617
#                                                    Tissue-resident cDC2          -1.964
#                                                    Vγ4 T cells                   -1.137
#                                                    Vγ6 T cells                   -1.190
#
#                                                                                  HDI 97%  \
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                            0.846
#                                                    cDC2                            1.895
#                                                    Conventional CD4+ T cells       0.618
#                                                    Cytotoxic CD8+ T cells          1.511
#                                                    Dendritic epidermal T cells    -2.364
#                                                    DoubleNegative T cells          0.072
#                                                    Foxp3+ Tregs                    1.710
#                                                    ILC2                           -0.627
#                                                    Langerhans cells                0.000
#                                                    M1-like Macrophages             2.528
#                                                    Mast cells                     -0.798
#                                                    Mature Monocytes                1.881
#                                                    MHCII+Ccr2+ Macrophages         1.717
#                                                    mo-DCs                          2.585
#                                                    Monocytes                       2.976
#                                                    mregDCs                         2.432
#                                                    Neutrophils                     3.361
#                                                    NK cells                        0.996
#                                                    pDC                             1.848
#                                                    Proliferative CD4+ T cells      1.375
#                                                    Proliferative DγδT cells        1.219
#                                                    Proliferative Macrophages       1.360
#                                                    Resident M2-like Macrophages    0.804
#                                                    Selenop+ M2-like Macrophages    1.303
#                                                    Slamf9+ Macrophages             2.686
#                                                    Tissue-resident cDC2            0.595
#                                                    Vγ4 T cells                     0.506
#                                                    Vγ6 T cells                     0.254
#
#                                                                                     SD  \
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                          0.410
#                                                    cDC2                          0.637
#                                                    Conventional CD4+ T cells     0.331
#                                                    Cytotoxic CD8+ T cells        0.664
#                                                    Dendritic epidermal T cells   0.451
#                                                    DoubleNegative T cells        0.534
#                                                    Foxp3+ Tregs                  0.507
#                                                    ILC2                          0.699
#                                                    Langerhans cells              0.000
#                                                    M1-like Macrophages           0.578
#                                                    Mast cells                    0.449
#                                                    Mature Monocytes              0.541
#                                                    MHCII+Ccr2+ Macrophages       0.523
#                                                    mo-DCs                        0.775
#                                                    Monocytes                     0.794
#                                                    mregDCs                       0.701
#                                                    Neutrophils                   0.649
#                                                    NK cells                      0.428
#                                                    pDC                           0.627
#                                                    Proliferative CD4+ T cells    0.465
#                                                    Proliferative DγδT cells      0.383
#                                                    Proliferative Macrophages     0.457
#                                                    Resident M2-like Macrophages  0.234
#                                                    Selenop+ M2-like Macrophages  0.431
#                                                    Slamf9+ Macrophages           0.636
#                                                    Tissue-resident cDC2          0.675
#                                                    Vγ4 T cells                   0.304
#                                                    Vγ6 T cells                   0.313
#
#                                                                                  Inclusion probability  \
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                                       0.373600
#                                                    cDC2                                       0.809800
#                                                    Conventional CD4+ T cells                  0.318867
#                                                    Cytotoxic CD8+ T cells                     0.401600
#                                                    Dendritic epidermal T cells                1.000000
#                                                    DoubleNegative T cells                     0.831867
#                                                    Foxp3+ Tregs                               0.518200
#                                                    ILC2                                       0.959867
#                                                    Langerhans cells                           0.000000
#                                                    M1-like Macrophages                        0.987600
#                                                    Mast cells                                 0.999867
#                                                    Mature Monocytes                           0.409400
#                                                    MHCII+Ccr2+ Macrophages                    0.885467
#                                                    mo-DCs                                     0.602267
#                                                    Monocytes                                  0.945867
#                                                    mregDCs                                    0.502467
#                                                    Neutrophils                                0.998133
#                                                    NK cells                                   0.296733
#                                                    pDC                                        0.455200
#                                                    Proliferative CD4+ T cells                 0.386667
#                                                    Proliferative DγδT cells                   0.449267
#                                                    Proliferative Macrophages                  0.419667
#                                                    Resident M2-like Macrophages               0.308133
#                                                    Selenop+ M2-like Macrophages               0.675267
#                                                    Slamf9+ Macrophages                        0.946800
#                                                    Tissue-resident cDC2                       0.597333
#                                                    Vγ4 T cells                                0.332733
#                                                    Vγ6 T cells                                0.403267
#
#                                                                                  Expected Sample  \
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                                65.372590
#                                                    cDC2                               239.296404
#                                                    Conventional CD4+ T cells           79.926148
#                                                    Cytotoxic CD8+ T cells              17.358860
#                                                    Dendritic epidermal T cells         92.908862
#                                                    DoubleNegative T cells              91.876032
#                                                    Foxp3+ Tregs                        91.800712
#                                                    ILC2                                25.154093
#                                                    Langerhans cells                    86.582962
#                                                    M1-like Macrophages                343.594640
#                                                    Mast cells                          91.743778
#                                                    Mature Monocytes                    33.052693
#                                                    MHCII+Ccr2+ Macrophages            399.330964
#                                                    mo-DCs                              26.042186
#                                                    Monocytes                          154.830300
#                                                    mregDCs                             73.791482
#                                                    Neutrophils                        272.163388
#                                                    NK cells                            25.231748
#                                                    pDC                                  6.693273
#                                                    Proliferative CD4+ T cells          24.559606
#                                                    Proliferative DγδT cells            68.244924
#                                                    Proliferative Macrophages           49.605567
#                                                    Resident M2-like Macrophages       100.796442
#                                                    Selenop+ M2-like Macrophages       450.207732
#                                                    Slamf9+ Macrophages                255.114220
#                                                    Tissue-resident cDC2                30.726970
#                                                    Vγ4 T cells                        198.562330
#                                                    Vγ6 T cells                        223.431093
#
#                                                                                  log2-fold change
# Covariate                                          Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_W... cDC1                                  0.531569
#                                                    cDC2                                  2.001098
#                                                    Conventional CD4+ T cells             0.531569
#                                                    Cytotoxic CD8+ T cells                0.531569
#                                                    Dendritic epidermal T cells          -4.287730
#                                                    DoubleNegative T cells               -0.740401
#                                                    Foxp3+ Tregs                          1.198840
#                                                    ILC2                                 -2.079828
#                                                    Langerhans cells                      0.531569
#                                                    M1-like Macrophages                   2.918306
#                                                    Mast cells                           -1.687445
#                                                    Mature Monocytes                      0.531569
#                                                    MHCII+Ccr2+ Macrophages               1.897351
#                                                    mo-DCs                                1.592837
#                                                    Monocytes                             2.925327
#                                                    mregDCs                               1.648418
#                                                    Neutrophils                           3.662650
#                                                    NK cells                              0.531569
#                                                    pDC                                   0.531569
#                                                    Proliferative CD4+ T cells            0.531569
#                                                    Proliferative DγδT cells              0.531569
#                                                    Proliferative Macrophages             0.531569
#                                                    Resident M2-like Macrophages          0.531569
#                                                    Selenop+ M2-like Macrophages          1.491836
#                                                    Slamf9+ Macrophages                   2.656094
#                                                    Tissue-resident cDC2                 -0.499903
#                                                    Vγ4 T cells                           0.531569
#                                                    Vγ6 T cells                           0.531569

# %%
# Filter out all credible effects
results.credible_effects()
# Out:
# Covariate                                                      Cell Type
# C(sample_id, Treatment('Z1_WT_CD45pos'))[T.Z1_WT_IMQ_CD45pos]  cDC1                            False
#                                                                cDC2                             True
#                                                                Conventional CD4+ T cells       False
#                                                                Cytotoxic CD8+ T cells          False
#                                                                Dendritic epidermal T cells      True
#                                                                DoubleNegative T cells           True
#                                                                Foxp3+ Tregs                     True
#                                                                ILC2                             True
#                                                                Langerhans cells                False
#                                                                M1-like Macrophages              True
#                                                                Mast cells                       True
#                                                                Mature Monocytes                False
#                                                                MHCII+Ccr2+ Macrophages          True
#                                                                mo-DCs                           True
#                                                                Monocytes                        True
#                                                                mregDCs                          True
#                                                                Neutrophils                      True
#                                                                NK cells                        False
#                                                                pDC                             False
#                                                                Proliferative CD4+ T cells      False
#                                                                Proliferative DγδT cells        False
#                                                                Proliferative Macrophages       False
#                                                                Resident M2-like Macrophages    False
#                                                                Selenop+ M2-like Macrophages     True
#                                                                Slamf9+ Macrophages              True
#                                                                Tissue-resident cDC2             True
#                                                                Vγ4 T cells                     False
#                                                                Vγ6 T cells                     False
# Name: Final Parameter, dtype: bool

# %% [markdown]
# **DATA INTERPRETATION**
#
# In the previous analysis, we see multiple credible changes on cell type composition between tissues. For instance, there is ...

# %% [markdown]
# ### Saving results

# %%
# Save all information as pickle object
results.save(f"results/scCODA_celltypes_{comparison_name}.pickle")

# Save all information as tsv file
results.to_dataframe().to_csv(f"results/tables/scCODA_celltypes_{comparison_name}_allinfo.tsv", sep='\t')

# Save effect information as tsv file
results.effect_df.to_csv(f"results/tables/scCODA_celltypes_{comparison_name}_effect.tsv", sep='\t')
